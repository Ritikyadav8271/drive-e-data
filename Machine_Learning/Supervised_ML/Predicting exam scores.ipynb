# %%
Independent Variable (X) -> Hours Studies
Dependent Variable (y) -> Exam Score

Our goal => find the best-fitting line that predicts exam score from study hours.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
hours = np.array([1,2,4,5,7,8,9]).reshape(-1,1)
scores = np.array([50,55,70,85,90,95])

# %%
plt.scatter(hours,scores,color = "blue")
p
