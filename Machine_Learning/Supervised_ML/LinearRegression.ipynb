# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_excel(r"E:\MachineLearning\placement_data.xlsx")

# %%
data.head()
# Out:
#    CGPA  Package_LPA
# 0  7.50        10.35
# 1  9.80        14.76
# 2  8.93        13.48
# 3  8.39        12.86
# 4  6.62        10.38

# %%
data.shape
# Out:
# (300, 2)

# %%
data.head()
# Out:
#    CGPA  Package_LPA
# 0  7.50        10.35
# 1  9.80        14.76
# 2  8.93        13.48
# 3  8.39        12.86
# 4  6.62        10.38

# %%
plt.scatter(data["CGPA"],data["Package_LPA"])
plt.xlabel("cgpa")
plt.ylabel("package")
plt.show()

# %%
X = data.iloc[:,0:1] # CGPA
y = data.iloc[:,-1] # package_LPA

# %%
X_trian, X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_trian,y_train)
# Out:
# LinearRegression()

# %%
predicted_value = lr.predict(X_test.iloc[0].values.reshape(1,-1))
# Out:
# C:\Users\Ritikyadav\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Predicted Package (LPA):", predicted_value[0])
print("Actual Package (LPA):", y_test.iloc[0])
# Out:
# Predicted Package (LPA): 9.232983119510891
# Actual Package (LPA): 9.65

# %%
y_test
# Out:
# 98      9.65
# 259     9.83
# 184    10.71
# 256    13.88
# 29      8.78
# 254    10.77
# 7      13.84
# 13     11.20
# 230    14.40
# 91     13.10
# 284    12.73
# 127    14.94
# 30     12.36
# 241    14.94
# 113    13.99
# 84     11.33
# 99     10.15
# 140    13.94
# 144    11.34
# 94     13.30
# 35     12.93
# 3      12.86
# 173    11.15
# 175    11.04
# 215     9.48
# 89     12.45
# 203    15.01
# 193    12.17
# 266    12.97
# 281    11.99
# 131    10.86
# 209    10.41
# 271    14.43
# 161    13.09
# 176    12.29
# 174    12.93
# 245    14.28
# 289    11.84
# 74     12.39
# 109     8.65
# 155    10.44
# 65     12.03
# 41     11.92
# 11     13.98
# 293    10.85
# 240    15.55
# 130    10.79
# 114    13.06
# 77      8.50
# 171    10.04
# 235    14.22
# 272    14.00
# 134    13.82
# 214    12.37
# 151    10.56
# 10      9.00
# 159    12.60
# 199    14.65
# 232    13.46
# 180    11.30
# Name: Package_LPA, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Step 1: Create sample data
X = np.array([[1], [2], [3], [4], [5], [6], [7], [8]])
y = np.array([30, 45, 52, 60, 63, 70, 78, 85])

# Step 2: Train the model
model = LinearRegression()
model.fit(X, y)

# Step 3: Predict values
y_pred = model.predict(X)

# Step 4: Calculate residuals
residuals = y - y_pred

# Step 5: Plot residuals
plt.figure(figsize=(8, 5))
plt.scatter(y_pred, residuals, color='blue', label='Residuals')
plt.axhline(y=0, color='red', linestyle='--', label='Zero Error Line')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals (Actual - Predicted)')
plt.title('Residual Plot')
plt.legend()
plt.show()
