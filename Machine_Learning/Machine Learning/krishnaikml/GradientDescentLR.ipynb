# %% [markdown]
# Gradient Descent in an optimization algo used in the lr to find the best fit-fit line for the data.

# %% [markdown]
# -> It works by gradually adjusting the line's slope and intercept to reduce the diff b/t acutal and predicted values.
#
# -> This process helps the model make accurate predication by minimizing erros step by step.

# %% [markdown]
# That's where gradient descent play an important role even for:
# -> large datasets.
# -> Complex, high-dimensional problems.
